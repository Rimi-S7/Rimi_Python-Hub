# %%
import pandas as pd

# Import library

# %%
df = pd.read_csv(r"C:\Users\DELL\Downloads\Sales Dataset.csv")

# Dataframe setup

# %%
df = df.drop_duplicates()

# Removing duplicates

# %%
df.info()

# Reading Information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1194 entries, 0 to 1193
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      1194 non-null   object
#  1   Amount        1194 non-null   int64
#  2   Profit        1194 non-null   int64
#  3   Quantity      1194 non-null   int64
#  4   Category      1194 non-null   object
#  5   Sub-Category  1194 non-null   object
#  6   PaymentMode   1194 non-null   object
#  7   Order Date    1194 non-null   object
#  8   CustomerName  1194 non-null   object
#  9   State         1194 non-null   object
#  10  City          1194 non-null   object
#  11  Year-Month    1194 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 112.1+ KB

# %%
df.isnull()

# Checking null values
# Out:
#       Order ID  Amount  Profit  Quantity  Category  Sub-Category  PaymentMode  \
# 0        False   False   False     False     False         False        False
# 1        False   False   False     False     False         False        False
# 2        False   False   False     False     False         False        False
# 3        False   False   False     False     False         False        False
# 4        False   False   False     False     False         False        False
# ...        ...     ...     ...       ...       ...           ...          ...
# 1189     False   False   False     False     False         False        False
# 1190     False   False   False     False     False         False        False
# 1191     False   False   False     False     False         False        False
# 1192     False   False   False     False     False         False        False
# 1193     False   False   False     False     False         False        False
#
# ...

# %%
df.isnull().sum()

# Checking null value count
# Out:
# Order ID        0
# Amount          0
# Profit          0
# Quantity        0
# Category        0
# Sub-Category    0
# PaymentMode     0
# Order Date      0
# CustomerName    0
# State           0
# City            0
# Year-Month      0
# dtype: int64

# %%
df.head(50)

# Checking the quality of table with top 50 rows
# Out:
#    Order ID  Amount  Profit  Quantity         Category      Sub-Category  \
# 0   B-26776    9726    1275         5      Electronics  Electronic Games
# 1   B-26776    9726    1275         5      Electronics  Electronic Games
# 2   B-26776    9726    1275         5      Electronics  Electronic Games
# 3   B-26776    4975    1330        14      Electronics          Printers
# 4   B-26776    4975    1330        14      Electronics          Printers
# 5   B-26776    4975    1330        14      Electronics          Printers
# 6   B-26942    1525     185        12  Office Supplies              Pens
# 7   B-26942    1525     185        12  Office Supplies              Pens
# 8   B-26640     883     117        10      Electronics           Laptops
# 9   B-26640    8127    3551        16        Furniture            Tables
# 10  B-25890    2516     734        19        Furniture            Chairs
# 11  B-25102    2975     462        14  Office Supplies              Pens
# ...

# %%
df.tail(50)

# Checking the quality of table with bottom 50 rows
# Out:
#      Order ID  Amount  Profit  Quantity         Category      Sub-Category  \
# 1143  B-25684    3560    1335        15      Electronics  Electronic Games
# 1144  B-26612    6528      76         9      Electronics            Phones
# 1145  B-26612    8930    3374        12        Furniture             Sofas
# 1146  B-25839    4521    1778         9  Office Supplies             Paper
# 1147  B-25898    7091    2317        10        Furniture             Sofas
# 1148  B-26120    2101     287         8  Office Supplies              Pens
# 1149  B-26120    2101     287         8  Office Supplies              Pens
# 1150  B-26426    8644    1968         9  Office Supplies             Paper
# 1151  B-26309    6672    3319         4        Furniture            Tables
# 1152  B-26309    6672    3319         4        Furniture            Tables
# 1153  B-26789    4699     103        12  Office Supplies           Binders
# ...

# %%
df['Amount'].max()

# Maximum Sale Amount
# Out:
# 9992

# %%
df['Amount'].min()

# Minimum Sale Amount
# Out:
# 508

# %%
df['Amount'].mean()

# Average Sale Amount
# Out:
# 5178.089614740368

# %%
df[df['Quantity'] == 20]

# Sale order list where purchase items list 20
# Out:
#      Order ID  Amount  Profit  Quantity         Category      Sub-Category  \
# 22    B-25104    2939     894        20  Office Supplies           Binders
# 27    B-26232    5219    1180        20  Office Supplies           Binders
# 28    B-26232    5219    1180        20  Office Supplies           Binders
# 29    B-25394    3686     760        20  Office Supplies              Pens
# 30    B-25394    3686     760        20  Office Supplies              Pens
# 64    B-25372    1016     172        20        Furniture            Tables
# 104   B-25690     523      95        20      Electronics          Printers
# 120   B-25936    9992    3696        20  Office Supplies              Pens
# 121   B-25936    9992    3696        20  Office Supplies              Pens
# 122   B-25936    9992    3696        20  Office Supplies              Pens
# 126   B-25884    9538    3158        20      Electronics          Printers
# ...

# %%
df2 = df.groupby('Category').count().sort_values(by = 'Quantity', ascending = False)
df2

# Checking most purchase items in category
# Out:
#                  Order ID  Amount  Profit  Quantity  Sub-Category  \
# Category
# Furniture             407     407     407       407           407
# Office Supplies       399     399     399       399           399
# Electronics           388     388     388       388           388
#
#                  PaymentMode  Order Date  CustomerName  State  City  \
# Category
# Furniture                407         407           407    407   407
# Office Supplies          399         399           399    399   399
# Electronics              388         388           388    388   388
#
#                  Year-Month
# Category
# Furniture               407
# Office Supplies         399
# Electronics             388

# %%
len(df[df['PaymentMode'] == 'Debit Card'])

# How many people have bought with Debit Card
# Out:
# 260

# %%
df[(df['State'] == "Texas") & (df['Amount'] > 9000)]

# Purchase amount greater than 9000 in Texas State
# Out:
#      Order ID  Amount  Profit  Quantity         Category      Sub-Category  \
# 54    B-26470    9683    1014         5      Electronics          Printers
# 55    B-26470    9683    1014         5      Electronics          Printers
# 109   B-26464    9236    2899         5      Electronics           Laptops
# 121   B-25936    9992    3696        20  Office Supplies              Pens
# 124   B-25936    9619    3420         7  Office Supplies           Binders
# 136   B-26293    9768    4518         8        Furniture            Tables
# 162   B-26332    9835    2571        16        Furniture            Tables
# 165   B-26332    9691    3056        13  Office Supplies           Markers
# 233   B-25885    9704    4339        12  Office Supplies              Pens
# 376   B-25241    9905     633        17  Office Supplies              Pens
# 607   B-26843    9612    2572        17  Office Supplies              Pens
# ...

# %%
df.groupby(['CustomerName']).max().sort_values(by = 'Amount', ascending = False).head(5)

# Top 5 most purchasing customers
# Out:
#                  Order ID  Amount  Profit  Quantity         Category  \
# CustomerName
# Patrick Williams  B-25936    9992    3696        20  Office Supplies
# Brent Hernandez   B-25936    9992    3696        20  Office Supplies
# Susan Burke       B-25936    9992    3696        20  Office Supplies
# Tammy Anthony     B-25861    9989    3930        19        Furniture
# Jennifer Chase    B-25861    9989    3930        19        Furniture
#
#                  Sub-Category PaymentMode  Order Date     State       City
# CustomerName
# Patrick Williams         Pens         UPI  2021-10-09  New York  Rochester
# Brent Hernandez          Pens         UPI  2022-08-29  New York  Rochester
# Susan Burke              Pens         UPI  2022-04-15     Texas     Austin
# Tammy Anthony          Tables  Debit Card  2022-03-28      Ohio  Cleveland
# Jennifer Chase         Tables  Debit Card  2023-07-15  New York    Buffalo

# %%
df[df['CustomerName'].str.contains("Hunt")]

# Checking customer's name with last name is "Hunt"
# Out:
#      Order ID  Amount  Profit  Quantity         Category Sub-Category  \
# 136   B-26293    9768    4518         8        Furniture       Tables
# 137   B-26293    4968     934         5        Furniture        Sofas
# 138   B-26293    1731     149         4      Electronics      Laptops
# 172   B-25303     770     241        11        Furniture        Sofas
# 614   B-26906    3665     802         4  Office Supplies      Markers
# 1090  B-25444    7626     229         5  Office Supplies         Pens
# 1190  B-26298    2082     642         8      Electronics       Phones
#
#       PaymentMode  Order Date     CustomerName     State         City
# 136   Credit Card  2021-11-26     Michael Hunt     Texas       Dallas
# 137    Debit Card  2021-11-26     Michael Hunt     Texas       Dallas
# 138           EMI  2021-11-26     Michael Hunt     Texas       Dallas
# 172           COD  2023-03-04  Michelle Hunter      Ohio   Cincinnati
# ...

# %%
df.shape

# Checking total rows and columns
# Out:
# (1194, 12)

# %%
df = df.drop('Year-Month', axis = 1)

# Drop unnecessary column

# %%
df = df[['Order ID','CustomerName','Amount','Profit','Quantity','Category','Sub-Category','Order Date','PaymentMode','State','City']]

# Reorder the columns

# %%
df.groupby('Category').describe()

# Showing descriptive output in 'Category'
# Out:
#                 Amount                                                   \
#                  count         mean          std    min     25%     50%
# Category
# Electronics      388.0  5294.989691  2781.444028  523.0  2801.0  5313.0
# Furniture        407.0  5009.024570  2761.400440  508.0  2695.0  5193.0
# Office Supplies  399.0  5236.867168  2869.801962  514.0  2966.0  4904.0
#
#                                  Profit                                  \
#                      75%     max  count         mean          std   min
# Category
# Electronics      7750.75  9952.0  388.0  1336.546392  1077.663951  50.0
# Furniture        7345.00  9989.0  407.0  1328.113022  1115.166725  54.0
# Office Supplies  7838.00  9992.0  399.0  1382.393484  1160.608027  51.0
#
#                                                 Quantity                       \
#                    25%     50%      75%     max    count       mean       std
# Category
# ...

# %%
df.corr(numeric_only = True)

# Correlation
# Out:
#             Amount    Profit  Quantity
# Amount    1.000000  0.675285  0.044631
# Profit    0.675285  1.000000  0.066088
# Quantity  0.044631  0.066088  1.000000

# %%
sns.heatmap(df.corr(numeric_only = True), annot = True)

# Showing heatmap
# Out:
# <Axes: >
